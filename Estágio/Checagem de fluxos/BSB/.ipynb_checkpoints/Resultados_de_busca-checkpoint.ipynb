# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import re
import os 
path = r"C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB" 
os.chdir(path)
print(os.getcwd())
# %matplotlib inline
novo = open("busca.txt", "a")
# Out:
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB

# %%
for diretorio, subpastas, arquivos in os.walk(path):
    for arquivo in arquivos:
        print(os.path.join(diretorio, arquivo))
# Out:
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA01     500  PARANAITA.txt
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA01     500  PARANATINGA.txt
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA1      230  ROSANA.txt
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA1      440  AGUA AZUL.txt
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA1      440  ALTA PAULISTA.txt
# C:\Users\DUARTE\Documents\GitHub\AllTheCodes\Estágio\Checagem de fluxos\BSB\20220125_152200_152259_01_OpenPDC_ONS_BSB\BA1      440  BAGUACU.txt
# ...

# %%
nomes= []
for x in range(len(arquivos)):
    resultado=re.split(r'.txt',arquivos[x])
    nomes.append(resultado[0])
    novo.write(f'{resultado[0]}\n')
print(nomes)
novo.close()
# Out:
# ['BA01     500  PARANAITA', 'BA01     500  PARANATINGA', 'BA1      230  ROSANA', 'BA1      440  AGUA AZUL', 'BA1      440  ALTA PAULISTA', 'BA1      440  BAGUACU', 'BA1      440  BRACELL', 'BA1      500  ARINOS 2', 'BA1      500  BACABEIRA', 'BA1      500  CLAUDIA', 'BA1      500  MARITUBA', 'BA1      500  MUTUM', 'BA1      500  RIBEIRAOZINHO', 'BA1      500  RIO NOVO SUL', 'BA1110   500  ACARAU III', 'BA1110   500  PARNAIBA III', 'BA1110   500  TIANGUA II', 'BA2      230  ROSANA', 'BA2      440  AGUA AZUL', 'BA2      440  ALTA PAULISTA', 'BA2      440  BAGUACU', 'BA2      440  BRACELL', 'BA2      500  ARINOS 2', 'BA2      500  BACABEIRA', 'BA2      500  MARITUBA', 'BA2      500  MUTUM', 'BA2      500  RIO NOVO SUL', 'BA2220   500  ACARAU III', 'BA2220   500  PARNAIBA III', 'BA2220   500  TIANGUA II', 'BA601    345  RIO NOVO SUL', 'BAA      500  IBIUNA', 'BAA      500  JANAUBA 3', 'BAA      525  AREIA', 'BAA      525  C.NOVOS', 'BAA      525  ITA', 'BAA      525  NOVA STA RITA', 'BAA
# ...

# %%
len(nomes)
# Out:
# 246
