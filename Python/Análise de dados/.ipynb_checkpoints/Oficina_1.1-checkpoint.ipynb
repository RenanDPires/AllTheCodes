# %%
import pandas as pd

# %%
df = pd.read_csv('drinks.txt')

# %% [markdown]
# # Pré-visualização

# %%
df.head()
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol
# 0                           0.0
# 1                           4.9
# 2                           0.7
# 3                          12.4
# 4                           5.9

# %% [markdown]
# # Verificação de tipo de dado em cada coluna

# %%
df.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %% [markdown]
# # 1- Qual a média e desvio padrão do consumo de cerveja, licor, vinho e total de álcool?

# %%
df.mean() #Média
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
df.std() #Mediana
# Out:
# beer_servings                   101.143103
# spirit_servings                  88.284312
# wine_servings                    79.697598
# total_litres_of_pure_alcohol      3.773298
# dtype: float64

# %% [markdown]
# # 2- Qual o consumo de licor na França?

# %%
df[df['country'] == 'France']['spirit_servings']
# Out:
# 61    151
# Name: spirit_servings, dtype: int64

# %% [markdown]
# Informa o index, o valor, a categoria e o tipo de dado.

# %% [markdown]
# # 3- Quais os 5 países nos quais se consome mais vinho?

# %%
df.sort_values(by='wine_servings', ascending = False).head(5)
# Out:
#          country  beer_servings  spirit_servings  wine_servings  \
# 61        France            127              151            370
# 136     Portugal            194               67            339
# 3        Andorra            245              138            312
# 166  Switzerland            185              100            280
# 48       Denmark            224               81            278
#
#      total_litres_of_pure_alcohol
# 61                           11.8
# 136                          11.0
# 3                            12.4
# 166                          10.2
# 48                           10.4

# %% [markdown]
# # 4- Quais os países nos quais o consumo de cerveja está acima da média?

# %%
df[df['beer_servings'] > df['beer_servings'].mean()].sort_values(by='beer_servings', ascending = False)
# Out:
#                           country  beer_servings  spirit_servings  \
# 117                       Namibia            376                3
# 45                 Czech Republic            361              170
# 62                          Gabon            347               98
# 65                        Germany            346              117
# 135                        Poland            343              215
# ..                            ...            ...              ...
# 11                        Bahamas            122              176
# 145  St. Vincent & the Grenadines            120              221
# 185                       Uruguay            115               35
# 189                       Vietnam            111                2
# 139                       Moldova            109              226
#
#      wine_servings  total_litres_of_pure_alcohol
# 117              1                           6.8
# 45             134                          11.8
# 62              59                           8.9
# 65             175                          11.3
# 135             56                          10.9
# ..             ...                           ...
# 11              51                           6.3
# 145             11                           6.3
# 185            220                           6.6
# 189              1                           2.0
# 139             18                           6.3
#
# [76 rows x 5 columns]

# %% [markdown]
# Odenado descendentemente.

# %% [markdown]
# # 5- Quais países nos quais o consumo total de álcool está acima do Brasil, em ordem do menor para o maior?

# %%
df[df['country'] == 'Brazil']['total_litres_of_pure_alcohol'] #verificação do valor do Brasil
# Out:
# 23    7.2
# Name: total_litres_of_pure_alcohol, dtype: float64

# %%
df[df['total_litres_of_pure_alcohol'] > 7.2].sort_values(by='total_litres_of_pure_alcohol', ascending = True)
# Out:
#                 country  beer_servings  spirit_servings  wine_servings  \
# 132            Paraguay            213              117             74
# 35                Chile            130              124            172
# 188           Venezuela            333              100              3
# 143   St. Kitts & Nevis            194              205             32
# 159        South Africa            225               76             81
# 32               Canada            240              122            100
# 44               Cyprus            192              154            113
# 6             Argentina            193               25            221
# 179              Uganda             45                9              0
# 67               Greece            133              112            218
# 184                 USA            249              158             84
# 62                Gabon            347               98             59
# 180             Ukraine            206              237             45
# 124             Nigeria             42                5              2
# 121         New Zealand            203               79            175
# 120         Netherlands            251               88            190
# 57              Estonia            224              194             59
# 151              Serbia            283              131            127
# 9               Austria            279               75            191
# 138         South Korea            140               16              9
# 60              Finland            263              133             97
# 160               Spain            284              157            112
# 144           St. Lucia            171              315             71
# 166         Switzerland            185              100            280
# 42              Croatia            230               87            254
# 25             Bulgaria            231              252             94
# 8             Australia            261               72            212
# 140             Romania            297              122            167
# 182      United Kingdom            219              126            195
# 48              Denmark            224               81            278
# 16              Belgium            295               84            212
# 93               Latvia            281              216             62
# 156            Slovenia            270               51            276
# 135              Poland            343              215             56
# 136            Portugal            194               67            339
# 75              Hungary            234              215            185
# 65              Germany            346              117            175
# 99           Luxembourg            236              133            271
# 155            Slovakia            196              293            116
# 81              Ireland            313              118            165
# 141  Russian Federation            247              326             73
# 45       Czech Republic            361              170            134
# 61               France            127              151            370
# 68              Grenada            199              438             28
# 3               Andorra            245              138            312
# 98            Lithuania            343              244             56
# 15              Belarus            142              373             42
#
#      total_litres_of_pure_alcohol
# 132                           7.3
# 35                            7.6
# 188                           7.7
# 143                           7.7
# 159                           8.2
# 32                            8.2
# 44                            8.2
# 6                             8.3
# 179                           8.3
# 67                            8.3
# 184                           8.7
# 62                            8.9
# 180                           8.9
# 124                           9.1
# 121                           9.3
# 120                           9.4
# 57                            9.5
# 151                           9.6
# 9                             9.7
# 138                           9.8
# 60                           10.0
# 160                          10.0
# 144                          10.1
# 166                          10.2
# 42                           10.2
# 25                           10.3
# 8                            10.4
# 140                          10.4
# 182                          10.4
# 48                           10.4
# 16                           10.5
# 93                           10.5
# 156                          10.6
# 135                          10.9
# 136                          11.0
# 75                           11.3
# 65                           11.3
# 99                           11.4
# 155                          11.4
# 81                           11.4
# 141                          11.5
# 45                           11.8
# 61                           11.8
# 68                           11.9
# 3                            12.4
# 98                           12.9
# 15                           14.4
