# %% [markdown]
# # 1- Importe as bibliotecas pandas, matplotlib e seaborn, usando a palavra mágica inline, para exibir as visualizações no notebook. Carregue os dados, que podem ser carregados pelo seaborn, utilizando a função load_dataset(‘mpg’), em um DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set(style="darkgrid")

carros= sns.load_dataset('mpg')
carros.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name
# 0          70    usa  chevrolet chevelle malibu
# 1          70    usa          buick skylark 320
# 2          70    usa         plymouth satellite
# 3          70    usa              amc rebel sst
# 4          70    usa                ford torino

# %% [markdown]
# # 2- Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos, em que seja possível diferenciar o país de origem (‘origin’). Sabendo disso, existe uma correlação entre a aceleração e o consumo? De que tipo? A correlação é a mesma para os diferentes países de origem? Você pode escolher a técnica que julgar mais adequada!

# %%
sns.lmplot(x='acceleration', y='mpg', hue='origin', data= carros)
plt.show()

# %% [markdown]
# R= Sim, em carros de toda origem observa-se que quanto mais os carros aceleram maior o seu consumo de combustível. Todas as correlações se mostraram do tipo: Baixa Correlação Positiva. O tipo de correlação é o mesmo para todos os países analisados, apesar de na Europa os dados serem mais 'espaçados' o que causa a ideia de Sem Correlação (que não será aceita, devido ser observado o contrário nos demais países).

# %% [markdown]
# # 3- Crie uma visualização que mostre a relação entre a aceleração (‘acceleration’) e o consumo de combustível (‘mpg’) dos veículos, em que seja possível visualizar o ano do modelo (model_year). Existe alguma relação entre as três variáveis?

# %%
sns.lmplot(x='acceleration', y='mpg', col='model_year', data= carros)
plt.show()

# %% [markdown]
# R= POR SEREM MUITOS ANOS (MUITAS VARIÁVEIS) EU DECIDI QUEBRAR A REPRESENTAÇÃO POR ANOS.
# Observamos alguns anos em que a correlação é:
# Baixa postiva: 74, 76, 77, 78, 80 e 81;
# Baixa negativa: 75 e 79;
# Alta positiva: 70, 71, 72 e 73;
# Sem Correlação: 82.
